# %%
import pandas as pd

# %%
import pandas as pd
df=pd.read_csv('train_Df64byy.csv')

def getNumber(x):
    return str(x)
df["Region_Code"]=df["Region_Code"].apply(getNumber)




#x1 = float("nan")
def getNumber(x):
    if x=="14+":
        return 15
    elif x!=x:
        return 0
    else:
        return int(float(x))
df["Holding_Policy_Duration"]=df["Holding_Policy_Duration"].apply(getNumber)


df['City_code_region']=df['City_Code']+df['Region_Code']


def getNumber(x):
    if x=="Rented":
        return 0
    elif x!=x:
        return 0
    else:
        return 1
df["Accomodation_Type"]=df["Accomodation_Type"].apply(getNumber)



#x1 = float("nan")
def getNumber(x):
    if x=="No":
        return 0
    elif x!=x:
        return 0
    else:
        return 1
df["Is_Spouse"]=df["Is_Spouse"].apply(getNumber)
#We have created a new column called "gender" and 
#filling it with values 1 ,2 based on the values of sex column
df.head()



#x1 = float("nan")
def getNumber(x):
    if x=="Individual":
        return 0
    elif x!=x:
        return 0
    else:
        return 1
df["Reco_Insurance_Type"]=df["Reco_Insurance_Type"].apply(getNumber)



def getNumber(x):
    if x!=x:
        return 0
    else:
        return int(float(x))
df["Holding_Policy_Type"]=df["Holding_Policy_Type"].apply(getNumber)
#We have created a new column called "gender" and 
#filling it with values 1 ,2 based on the values of sex column



df["Reco_Policy_Premium"]=df['Reco_Policy_Premium'].astype(int)



def getNumber(x):
    if x!=x:
        return 0
    else:
        return int(float(x[-1]))
df["Health Indicator"]=df["Health Indicator"].apply(getNumber)
#We have created a new column called "gender" and 
#filling it with values 1 ,2 based on the values of sex column
df.head()



df['diff_between_age']=df['Upper_Age']-df["Lower_Age"]


def getNumber(x):
    if x>14:
        return 1
    else:
        return 0
df["Holding_policy>0"]=df["Holding_Policy_Duration"].apply(getNumber)
#We have created a new column called "gender" and 
#filling it with values 1 ,2 based on the values of sex column
df.head()

df['Region_Code']=df['Region_Code'].astype(int)

def getNumber(x):
    if x!=x:
        return 0
    else:
        return (int(x[1:]))
df["City_Code"]=df["City_Code"].apply(getNumber)

df['Region_Code']=df['Region_Code'].astype(int)


del df['City_code_region']


df.head()
df.to_csv("train.csv",index=False)

# %%
import pandas as pd
df=pd.read_csv('test_YCcRUnU.csv')

def getNumber(x):
    return str(x)
df["Region_Code"]=df["Region_Code"].apply(getNumber)




#x1 = float("nan")
def getNumber(x):
    if x=="14+":
        return 15
    elif x!=x:
        return 0
    else:
        return int(float(x))
df["Holding_Policy_Duration"]=df["Holding_Policy_Duration"].apply(getNumber)


df['City_code_region']=df['City_Code']+df['Region_Code']


def getNumber(x):
    if x=="Rented":
        return 0
    elif x!=x:
        return 0
    else:
        return 1
df["Accomodation_Type"]=df["Accomodation_Type"].apply(getNumber)



#x1 = float("nan")
def getNumber(x):
    if x=="No":
        return 0
    elif x!=x:
        return 0
    else:
        return 1
df["Is_Spouse"]=df["Is_Spouse"].apply(getNumber)
#We have created a new column called "gender" and 
#filling it with values 1 ,2 based on the values of sex column
df.head()



#x1 = float("nan")
def getNumber(x):
    if x=="Individual":
        return 0
    elif x!=x:
        return 0
    else:
        return 1
df["Reco_Insurance_Type"]=df["Reco_Insurance_Type"].apply(getNumber)



def getNumber(x):
    if x!=x:
        return 0
    else:
        return int(float(x))
df["Holding_Policy_Type"]=df["Holding_Policy_Type"].apply(getNumber)
#We have created a new column called "gender" and 
#filling it with values 1 ,2 based on the values of sex column



df["Reco_Policy_Premium"]=df['Reco_Policy_Premium'].astype(int)



def getNumber(x):
    if x!=x:
        return 0
    else:
        return int(float(x[-1]))
df["Health Indicator"]=df["Health Indicator"].apply(getNumber)
#We have created a new column called "gender" and 
#filling it with values 1 ,2 based on the values of sex column
df.head()



df['diff_between_age']=df['Upper_Age']-df["Lower_Age"]


def getNumber(x):
    if x>14:
        return 1
    else:
        return 0
df["Holding_policy>0"]=df["Holding_Policy_Duration"].apply(getNumber)
#We have created a new column called "gender" and 
#filling it with values 1 ,2 based on the values of sex column
df.head()

df['Region_Code']=df['Region_Code'].astype(int)

def getNumber(x):
    if x!=x:
        return 0
    else:
        return (int(x[1:]))
df["City_Code"]=df["City_Code"].apply(getNumber)

df['Region_Code']=df['Region_Code'].astype(int)


del df['City_code_region']


df.head()
# Out:
#       ID  City_Code  Region_Code  Accomodation_Type  Reco_Insurance_Type  \
# 0  50883          1          156                  1                    0
# 1  50884          4            7                  1                    1
# 2  50885          1          564                  0                    0
# 3  50886          3         1177                  0                    0
# 4  50887          1          951                  1                    0
#
#    Upper_Age  Lower_Age  Is_Spouse  Health Indicator  Holding_Policy_Duration  \
# 0         30         30          0                 0                        6
# 1         69         68          1                 1                        3
# 2         28         28          0                 3                        2
# 3         23         23          0                 3                        3
# 4         75         75          0                 3                        0
#
# ...

# %%
df.to_csv("test.csv",index=False)

# %%
df=pd.read_csv('train_Df64byy.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50882 entries, 0 to 50881
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       50882 non-null  int64
#  1   City_Code                50882 non-null  object
#  2   Region_Code              50882 non-null  int64
#  3   Accomodation_Type        50882 non-null  object
#  4   Reco_Insurance_Type      50882 non-null  object
#  5   Upper_Age                50882 non-null  int64
#  6   Lower_Age                50882 non-null  int64
#  7   Is_Spouse                50882 non-null  object
#  8   Health Indicator         39191 non-null  object
#  9   Holding_Policy_Duration  30631 non-null  object
#  10  Holding_Policy_Type      30631 non-null  float64
#  11  Reco_Policy_Cat          50882 non-null  int64
#  12  Reco_Policy_Premium      50882 non-null  float64
#  13  Response                 50882 non-null  int64
# ...

# %%
df['Accomodation_Type'].unique()
# Out:
# array(['Rented', 'Owned'], dtype=object)

# %%
df['Reco_Insurance_Type'].unique()
# Out:
# array(['Individual', 'Joint'], dtype=object)

# %%
df['Is_Spouse'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Health Indicator'].unique()
# Out:
# array(['X1', 'X2', nan, 'X4', 'X3', 'X6', 'X5', 'X8', 'X7', 'X9'],
#       dtype=object)

# %%
df['Holding_Policy_Duration'].unique()
# Out:
# array(['14+', nan, '1.0', '3.0', '5.0', '9.0', '14.0', '7.0', '2.0',
#        '11.0', '10.0', '8.0', '6.0', '4.0', '13.0', '12.0'], dtype=object)

# %%
df['Reco_Policy_Cat'].unique()
# Out:
# array([22, 19, 16, 17,  1, 18, 21, 13, 20,  9,  2,  4, 12,  6, 14, 11,  3,
#         8,  7, 10, 15,  5], dtype=int64)

# %%
df['Reco_Policy_Premium'].unique()
# Out:
# array([11628., 30510.,  7450., ..., 25726.,  6156., 11374.])

# %%
df['Response'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df[df['Lower_Age']<=16]
# Out:
#           ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 180      181        C7         2503             Owned               Joint
# 235      236       C19          909             Owned               Joint
# 424      425       C11          750             Owned               Joint
# 566      567        C7         1080             Owned               Joint
# 680      681       C24         1935            Rented               Joint
# ...      ...       ...          ...               ...                 ...
# 50098  50099        C1          581             Owned               Joint
# 50245  50246       C18         1546            Rented               Joint
# 50295  50296       C15          837             Owned               Joint
# 50354  50355        C3          281             Owned               Joint
# 50833  50834       C23           54            Rented               Joint
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
df.describe()
# Out:
#                  ID   Region_Code     Upper_Age     Lower_Age  \
# count  50882.000000  50882.000000  50882.000000  50882.000000
# mean   25441.500000   1732.788707     44.856275     42.738866
# std    14688.512535   1424.081652     17.310271     17.319375
# min        1.000000      1.000000     18.000000     16.000000
# 25%    12721.250000    523.000000     28.000000     27.000000
# 50%    25441.500000   1391.000000     44.000000     40.000000
# 75%    38161.750000   2667.000000     59.000000     57.000000
# max    50882.000000   6194.000000     75.000000     75.000000
#
#        Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium      Response
# count         30631.000000     50882.000000         50882.000000  50882.000000
# mean              2.439228        15.115188         14183.950069      0.239947
# std               1.025923         6.340663          6590.074873      0.427055
# min               1.000000         1.000000          2280.000000      0.000000
# ...

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

num_cols = ['Upper_Age','Lower_Age']
plt.figure(figsize=(18,9))
df[num_cols].boxplot()
plt.title("Numerical variables in dataset", fontsize=20)
plt.show()

# %%
value_counts =df['Is_Spouse'].value_counts()

df_val_counts = pd.DataFrame(value_counts)
df_value_counts_weekend = df_val_counts.reset_index()
df_value_counts_weekend.columns = ['Is_Spouse', 'Response']

# %%
value_counts
# Out:
# No     42460
# Yes     8422
# Name: Is_Spouse, dtype: int64

# %%
df_value_counts_weekend.plot(kind='bar',x="Is_Spouse")
# Out:
# <AxesSubplot:xlabel='Is_Spouse'>

# %%
df.describe(include=['O'])
# Out:
#        City_Code Accomodation_Type Reco_Insurance_Type Is_Spouse  \
# count      50882             50882               50882     50882
# unique        36                 2                   2         2
# top           C1             Owned          Individual        No
# freq        8973             27951               40536     42460
#
#        Health Indicator Holding_Policy_Duration
# count             39191                   30631
# unique                9                      15
# top                  X1                     1.0
# freq              13010                    4499

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
df[['Is_Spouse','Response']].groupby(['Is_Spouse']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Is_Spouse ')
sns.countplot('Is_Spouse',hue='Response',data=df,ax=ax[1])
ax[1].set_title('Is_Spouse')
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
df[['Accomodation_Type','Response']].groupby(['Accomodation_Type']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Accomodation_Type')
sns.countplot('Accomodation_Type',hue='Response',data=df,ax=ax[1])
ax[1].set_title('Accomodation_Type')
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
df['Reco_Insurance_Type'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Reco_Insurance_Type')
ax[0].set_ylabel('Count')
sns.countplot('Reco_Insurance_Type',hue='Response',data=df,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
df['Health Indicator'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Health Indicator')
ax[0].set_ylabel('Count')
sns.countplot('Health Indicator',hue='Response',data=df,ax=ax[1])
ax[1].set_title('Health Indicator')
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
df['Holding_Policy_Duration'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Holding_Policy_Duration')
ax[0].set_ylabel('Count')
sns.countplot('Holding_Policy_Duration',hue='Response',data=df,ax=ax[1])
ax[1].set_title('Holding_Policy_Duration')
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
df['Holding_Policy_Duration'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Holding_Policy_Duration')
ax[0].set_ylabel('Count')
sns.countplot('Holding_Policy_Duration',hue='Response',data=df,ax=ax[1])
ax[1].set_title('Holding_Policy_Duration')
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
df['City_Code'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('City_Code')
ax[0].set_ylabel('Count')
sns.countplot('City_Code',hue='Response',data=df,ax=ax[1])
ax[1].set_title('City_Code')
plt.show()

# %%
data=df
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Response']==0].Upper_Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Response= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Response']==1].Upper_Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Response= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
data=df
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Response']==0].Lower_Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Response= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Response']==1].Lower_Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Response= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
data=df
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Response']==0].Reco_Policy_Premium.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Response= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Response']==1].Reco_Policy_Premium.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Response= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
def getNumber(x):
    return str(x)
df["Region_Code"]=df["Region_Code"].apply(getNumber)

# %%
df
# Out:
#           ID City_Code Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0          1        C3        3213            Rented          Individual
# 1          2        C5        1117             Owned               Joint
# 2          3        C5        3732             Owned          Individual
# 3          4       C24        4378             Owned               Joint
# 4          5        C8        2190            Rented          Individual
# ...      ...       ...         ...               ...                 ...
# 50877  50878        C4         845            Rented          Individual
# 50878  50879        C5        4188            Rented          Individual
# 50879  50880        C1         442            Rented          Individual
# 50880  50881        C1           4             Owned               Joint
# 50881  50882        C3        3866            Rented          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
#x1 = float("nan")
def getNumber(x):
    if x=="14+":
        return 15
    elif x!=x:
        return 0
    else:
        return int(float(x))
df["Holding_Policy_Duration"]=df["Holding_Policy_Duration"].apply(getNumber)
#We have created a new column called "gender" and 
#filling it with values 1 ,2 based on the values of sex column
df.head()
# Out:
#    ID City_Code Region_Code Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3        3213            Rented          Individual         36
# 1   2        C5        1117             Owned               Joint         75
# 2   3        C5        3732             Owned          Individual         32
# 3   4       C24        4378             Owned               Joint         52
# 4   5        C8        2190            Rented          Individual         44
#
#    Lower_Age Is_Spouse Health Indicator  Holding_Policy_Duration  \
# 0         36        No               X1                       15
# 1         22        No               X2                        0
# 2         32        No              NaN                        1
# 3         48        No               X1                       15
# 4         44        No               X2                        3
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response
# ...

# %%
df['City_code_region']=df['City_Code']+df['Region_Code']

# %%
len(df['Is_Spouse'].unique())
# Out:
# 2

# %%
#x1 = float("nan")
def getNumber(x):
    if x=="Rented":
        return 0
    elif x!=x:
        return 0
    else:
        return 1
df["Accomodation_Type"]=df["Accomodation_Type"].apply(getNumber)
#We have created a new column called "gender" and 
#filling it with values 1 ,2 based on the values of sex column
df.head()
# Out:
#    ID City_Code Region_Code  Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3        3213                  0          Individual         36
# 1   2        C5        1117                  1               Joint         75
# 2   3        C5        3732                  1          Individual         32
# 3   4       C24        4378                  1               Joint         52
# 4   5        C8        2190                  0          Individual         44
#
#    Lower_Age Is_Spouse Health Indicator  Holding_Policy_Duration  \
# 0         36        No               X1                       15
# 1         22        No               X2                        0
# 2         32        No              NaN                        1
# 3         48        No               X1                       15
# 4         44        No               X2                        3
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response  \
# ...

# %%
#x1 = float("nan")
def getNumber(x):
    if x=="No":
        return 0
    elif x!=x:
        return 0
    else:
        return 1
df["Is_Spouse"]=df["Is_Spouse"].apply(getNumber)
#We have created a new column called "gender" and 
#filling it with values 1 ,2 based on the values of sex column
df.head()
# Out:
#    ID City_Code Region_Code  Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3        3213                  0          Individual         36
# 1   2        C5        1117                  1               Joint         75
# 2   3        C5        3732                  1          Individual         32
# 3   4       C24        4378                  1               Joint         52
# 4   5        C8        2190                  0          Individual         44
#
#    Lower_Age  Is_Spouse Health Indicator  Holding_Policy_Duration  \
# 0         36          0               X1                       15
# 1         22          0               X2                        0
# 2         32          0              NaN                        1
# 3         48          0               X1                       15
# 4         44          0               X2                        3
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response  \
# ...

# %%
#x1 = float("nan")
def getNumber(x):
    if x=="Individual":
        return 0
    elif x!=x:
        return 0
    else:
        return 1
df["Reco_Insurance_Type"]=df["Reco_Insurance_Type"].apply(getNumber)
#We have created a new column called "gender" and 
#filling it with values 1 ,2 based on the values of sex column
df.head()
# Out:
#    ID City_Code Region_Code  Accomodation_Type  Reco_Insurance_Type  \
# 0   1        C3        3213                  0                    0
# 1   2        C5        1117                  1                    1
# 2   3        C5        3732                  1                    0
# 3   4       C24        4378                  1                    1
# 4   5        C8        2190                  0                    0
#
#    Upper_Age  Lower_Age  Is_Spouse Health Indicator  Holding_Policy_Duration  \
# 0         36         36          0               X1                       15
# 1         75         22          0               X2                        0
# 2         32         32          0              NaN                        1
# 3         52         48          0               X1                       15
# 4         44         44          0               X2                        3
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response  \
# ...

# %%
def getNumber(x):
    if x!=x:
        return 0
    else:
        return int(float(x))
df["Holding_Policy_Type"]=df["Holding_Policy_Type"].apply(getNumber)
#We have created a new column called "gender" and 
#filling it with values 1 ,2 based on the values of sex column
df.head()
# Out:
#    ID City_Code Region_Code  Accomodation_Type  Reco_Insurance_Type  \
# 0   1        C3        3213                  0                    0
# 1   2        C5        1117                  1                    1
# 2   3        C5        3732                  1                    0
# 3   4       C24        4378                  1                    1
# 4   5        C8        2190                  0                    0
#
#    Upper_Age  Lower_Age  Is_Spouse Health Indicator  Holding_Policy_Duration  \
# 0         36         36          0               X1                       15
# 1         75         22          0               X2                        0
# 2         32         32          0              NaN                        1
# 3         52         48          0               X1                       15
# 4         44         44          0               X2                        3
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response  \
# ...

# %%
df["Reco_Policy_Premium"]=df['Reco_Policy_Premium'].astype(int)

# %%
df['Health Indicator'].unique()
# Out:
# array(['X1', 'X2', nan, 'X4', 'X3', 'X6', 'X5', 'X8', 'X7', 'X9'],
#       dtype=object)

# %%
def getNumber(x):
    if x!=x:
        return 0
    else:
        return int(float(x[-1]))
df["Health Indicator"]=df["Health Indicator"].apply(getNumber)
#We have created a new column called "gender" and 
#filling it with values 1 ,2 based on the values of sex column
df.head()
# Out:
#    ID City_Code Region_Code  Accomodation_Type  Reco_Insurance_Type  \
# 0   1        C3        3213                  0                    0
# 1   2        C5        1117                  1                    1
# 2   3        C5        3732                  1                    0
# 3   4       C24        4378                  1                    1
# 4   5        C8        2190                  0                    0
#
#    Upper_Age  Lower_Age  Is_Spouse  Health Indicator  Holding_Policy_Duration  \
# 0         36         36          0                 1                       15
# 1         75         22          0                 2                        0
# 2         32         32          0                 0                        1
# 3         52         48          0                 1                       15
# 4         44         44          0                 2                        3
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50882 entries, 0 to 50881
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       50882 non-null  int64
#  1   City_Code                50882 non-null  object
#  2   Region_Code              50882 non-null  object
#  3   Accomodation_Type        50882 non-null  int64
#  4   Reco_Insurance_Type      50882 non-null  int64
#  5   Upper_Age                50882 non-null  int64
#  6   Lower_Age                50882 non-null  int64
#  7   Is_Spouse                50882 non-null  int64
#  8   Health Indicator         50882 non-null  int64
#  9   Holding_Policy_Duration  50882 non-null  int64
#  10  Holding_Policy_Type      50882 non-null  int64
#  11  Reco_Policy_Cat          50882 non-null  int64
#  12  Reco_Policy_Premium      50882 non-null  int32
#  13  Response                 50882 non-null  int64
# ...

# %%
df['diff_between_age']=df['Upper_Age']-df["Lower_Age"]

# %%
df["diff_between_age"].unique()
# Out:
# array([ 0, 53,  4,  2,  9, 33, 12,  6,  5, 37, 10,  1,  7, 19,  3, 38, 31,
#        25, 35, 11, 15, 34,  8, 21, 13, 29, 17, 45, 30, 18, 28, 27, 26, 20,
#        22, 40, 24, 39, 23, 47, 42, 43, 14, 32, 51, 49, 41, 16, 36, 55, 46,
#        57, 50, 48, 52, 44, 54, 56, 59, 58], dtype=int64)

# %%
def getNumber(x):
    if x>14:
        return 1
    else:
        return 0
df["Holding_policy>0"]=df["Holding_Policy_Duration"].apply(getNumber)
#We have created a new column called "gender" and 
#filling it with values 1 ,2 based on the values of sex column
df.head()
# Out:
#    ID City_Code Region_Code  Accomodation_Type  Reco_Insurance_Type  \
# 0   1        C3        3213                  0                    0
# 1   2        C5        1117                  1                    1
# 2   3        C5        3732                  1                    0
# 3   4       C24        4378                  1                    1
# 4   5        C8        2190                  0                    0
#
#    Upper_Age  Lower_Age  Is_Spouse  Health Indicator  Holding_Policy_Duration  \
# 0         36         36          0                 1                       15
# 1         75         22          0                 2                        0
# 2         32         32          0                 0                        1
# 3         52         48          0                 1                       15
# 4         44         44          0                 2                        3
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response  \
# ...

# %%
df["Holding_policy>0"].unique()
# Out:
# array([1, 0], dtype=int64)
